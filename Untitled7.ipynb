# %% [markdown]
# <a href="https://colab.research.google.com/github/meloarthur6470-hash/ALGESTDADOS20261/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos = ['ana','bruno','carla''diego','elena']
for alunos  in alunos:
    print(alunos)
# Out:
# ana
# bruno
# carladiego
# elena

# %%
notas = [6,65,7,5,9]
print(f"{notas[0]} e {notas[-1]}")
notas [1] = 10
notas.append(10)
print(f"quant.de notas:{len(notas)}")
# Out:
# 6 e 9
# quant.de notas:6

# %%
turma = ["Amanda","Arthur","carol","thaís"]
#a
print("letra A:")
for aluno in turma:
    print(f'presente:{aluno}')
turma.append('lindo arthur henrique')
#b
print('\nletra b:')
for aluno in turma:
        print(f'presente: {aluno}')
# Out:
# letra A:
# presente:Amanda
# presente:Arthur
# presente:carol
# presente:thaís
#
# letra b:
# presente: Amanda
# presente: Arthur
# presente: carol
# presente: thaís
# presente: lindo arthur henrique

# %%
# Crie uma lista chamada valores com pelo menos 6 números inteiros; em seguida, remova um elemento específico usando remove(), remova o último elemento com pop(), ordene a lista com sort() e, por fim, utilize um for para exibir cada valor da lista junto com sua posição (índice).
